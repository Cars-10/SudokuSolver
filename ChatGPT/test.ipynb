# %%
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/carstenlawrenz/GIT/SudokuSolver/ChatGPT/test.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/carstenlawrenz/GIT/SudokuSolver/ChatGPT/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from openai import OpenAI
#
# ImportError: cannot import name 'OpenAI' from 'openai' (/Users/carstenlawrenz/opt/anaconda3/envs/streamlit2023/lib/python3.11/site-packages/openai/__init__.py)
